# %%
imagesNames = ["defreitas/dns-proxy-server:2.18.0", "mongo:4.0.13", "redis:5.0.5", "rabbitmq:3.8.1", "memcached:1.5.16", "yg397/social-network-microservices:latest", "yg397/openresty-thrift:xenial", "yg397/media-frontend:xenial"]

# %%
import requests

for imageName in imagesNames:
    print(imageName)
    response = requests.get("http://localhost:8080/sum/" + imageName)
# Out:
# defreitas/dns-proxy-server:2.18.0
# mongo:4.0.13
# redis:5.0.5
# rabbitmq:3.8.1
# memcached:1.5.16
# yg397/social-network-microservices:latest
# yg397/openresty-thrift:xenial
# yg397/media-frontend:xenial

# %%
import pandas as pd
import matplotlib.pyplot as plt
from textwrap import wrap

sum_dict = {}
df_dict = {}
sum_sev_dict = {}
for imageName in imagesNames:
    print(imageName)
    fileName = imageName.replace("/","-").replace(":","-") + "-results.csv"
    df = pd.read_csv("../../results/" + fileName)
    print(df)

    ax = df.plot(kind="bar",x='sev_name', title=imageName + ' - vulnerabilities'); 
    ax.set_xlabel("severity level")
    ax.set_ylabel("number of vulnerabilities")
    plt.legend(loc='best')

    plt.savefig("../../results/" + fileName.replace("-results.csv",".png"))
    all_sum = df.sum().get("sum")
    print("\n\nSum of all: " + str(all_sum) + "\n\n")
    sum_dict[imageName] = all_sum
    df_dict[imageName] = df
    sum_sev_dict[imageName] = df[['sev_name','sum']].set_index('sev_name').to_dict().get("sum")
    
print(sum_sev_dict)
sum_df = pd.DataFrame(sum_sev_dict);
print(sum_df.T)
labels = list(sum_df.T.index)
labels = ['\n'.join(wrap(l, 12)) for l in labels]
print(labels)
ax = sum_df.T.plot(kind='bar', logy=True, figsize=(14,4))
ax.set_xlabel("image name")
ax.set_ylabel("number of vulnerabilities")
plt.xticks(range(0,len(labels)), labels, rotation='horizontal')
sum_df.T.to_csv("../../results/images-summary.csv")
plt.savefig("../../results/images-summary.png", bbox_inches="tight", pad_inches=0.5)
# Out:
# defreitas/dns-proxy-server:2.18.0
#      sev_name  clair  anchore  sum
# 0    CRITICAL      0        0    0
# 1        HIGH      0        2    2
# 2      MEDIUM      0       11   11
# 3         LOW     10        1   10
# 4  NEGLIGIBLE     35       29   35
# 5     UNKNOWN     19        0   19
#
#
# Sum of all: 77
#
#
# mongo:4.0.13
#      sev_name  clair  anchore  sum
# 0    CRITICAL      0        0    0
# 1        HIGH      0        0    0
# 2      MEDIUM     35       35   35
# 3         LOW     51       47   51
# 4  NEGLIGIBLE     25       23   25
# 5     UNKNOWN      0        0    0
#
#
# Sum of all: 111
#
#
# redis:5.0.5
#      sev_name  clair  anchore  sum
# 0    CRITICAL      0        0    0
# 1        HIGH      0        2    2
# 2      MEDIUM      0       11   11
# 3         LOW     10        1   10
# 4  NEGLIGIBLE     35       29   35
# 5     UNKNOWN     19        0   19
#
#
# Sum of all: 77
#
#
# rabbitmq:3.8.1
#      sev_name  clair  anchore  sum
# 0    CRITICAL      0        0    0
# 1        HIGH      0        0    0
# 2      MEDIUM     10       10   10
# 3         LOW     25       25   25
# 4  NEGLIGIBLE     11        9   11
# 5     UNKNOWN      0        0    0
#
#
# Sum of all: 46
#
#
# memcached:1.5.16
#      sev_name  clair  anchore  sum
# 0    CRITICAL      0        0    0
# 1        HIGH      0        2    2
# 2      MEDIUM      0       15   15
# 3         LOW     12        2   12
# 4  NEGLIGIBLE     39       31   39
# 5     UNKNOWN     22        0   22
#
#
# Sum of all: 90
#
#
# yg397/social-network-microservices:latest
#      sev_name  clair  anchore  sum
# 0    CRITICAL      0        0    0
# 1        HIGH      0       11   11
# 2      MEDIUM    207      207  207
# 3         LOW    314      309  314
# 4  NEGLIGIBLE     50       48   50
# 5     UNKNOWN      0        0    0
#
#
# Sum of all: 582
#
#
# yg397/openresty-thrift:xenial
#      sev_name  clair  anchore  sum
# 0    CRITICAL      0        0    0
# 1        HIGH      2        2    2
# 2      MEDIUM     75       75   75
# 3         LOW    247      242  247
# 4  NEGLIGIBLE     41       39   41
# 5     UNKNOWN      0        0    0
#
#
# Sum of all: 365
#
#
# yg397/media-frontend:xenial
#      sev_name  clair  anchore  sum
# 0    CRITICAL      0        0    0
# 1        HIGH     15       15   15
# 2      MEDIUM    237      237  237
# 3         LOW    421      415  421
# 4  NEGLIGIBLE     82       80   82
# 5     UNKNOWN      0        0    0
#
#
# Sum of all: 755
#
#
# {'defreitas/dns-proxy-server:2.18.0': {'CRITICAL': 0, 'HIGH': 2, 'MEDIUM': 11, 'LOW': 10, 'NEGLIGIBLE': 35, 'UNKNOWN': 19}, 'mongo:4.0.13': {'CRITICAL': 0, 'HIGH': 0, 'MEDIUM': 35, 'LOW': 51, 'NEGLIGIBLE': 25, 'UNKNOWN': 0}, 'redis:5.0.5': {'CRITICAL': 0, 'HIGH': 2, 'MEDIUM': 11, 'LOW': 10, 'NEGLIGIBLE': 35, 'UNKNOWN': 19}, 'rabbitmq:3.8.1': {'CRITICAL': 0, 'HIGH': 0, 'MEDIUM': 10, 'LOW': 25, 'NEGLIGIBLE': 11, 'UNKNOWN': 0}, 'memcached:1.5.16': {'CRITICAL': 0, 'HIGH': 2, 'MEDIUM': 15, 'LOW': 12, 'NEGLIGIBLE': 39, 'UNKNOWN': 22}, 'yg397/social-network-microservices:latest': {'CRITICAL': 0, 'HIGH': 11, 'MEDIUM': 207, 'LOW': 314, 'NEGLIGIBLE': 50, 'UNKNOWN': 0}, 'yg397/openresty-thrift:xenial': {'CRITICAL': 0, 'HIGH': 2, 'MEDIUM': 75, 'LOW': 247, 'NEGLIGIBLE': 41, 'UNKNOWN': 0}, 'yg397/media-frontend:xenial': {'CRITICAL': 0, 'HIGH': 15, 'MEDIUM': 237, 'LOW': 421, 'NEGLIGIBLE': 82, 'UNKNOWN': 0}}
#                                            CRITICAL  HIGH  MEDIUM  LOW  \
# defreitas/dns-proxy-server:2.18.0                 0     2      11   10
# mongo:4.0.13                                      0     0      35   51
# redis:5.0.5                                       0     2      11   10
# rabbitmq:3.8.1                                    0     0      10   25
# memcached:1.5.16                                  0     2      15   12
# yg397/social-network-microservices:latest         0    11     207  314
# yg397/openresty-thrift:xenial                     0     2      75  247
# yg397/media-frontend:xenial                       0    15     237  421
#
#                                            NEGLIGIBLE  UNKNOWN
# defreitas/dns-proxy-server:2.18.0                  35       19
# mongo:4.0.13                                       25        0
# redis:5.0.5                                        35       19
# rabbitmq:3.8.1                                     11        0
# memcached:1.5.16                                   39       22
# yg397/social-network-microservices:latest          50        0
# yg397/openresty-thrift:xenial                      41        0
# yg397/media-frontend:xenial                        82        0
# ['defreitas/dn\ns-proxy-serv\ner:2.18.0', 'mongo:4.0.13', 'redis:5.0.5', 'rabbitmq:3.8\n.1', 'memcached:1.\n5.16', 'yg397/social\n-network-mic\nroservices:l\natest', 'yg397/openre\nsty-thrift:x\nenial', 'yg397/media-\nfrontend:xen\nial']
